# %%
import json

# Определение осей
axis_a = [
    "Операционные риски процессов",
    "Проектные риски (бизнес-проекты)",
    "Комплаенс и регуляторные риски",
    "Финансовые риски и риски отчётности",
    "ИТ- и киберриски",
    "Риски третьих сторон / поставщиков",
    "Стратегические риски",
    "Риски мошенничества (fraud)"
]

axis_b = [
    "Объяснить концепцию/термин",
    "Идентифицировать риски в сценарии",
    "Оценить риск (вероятность × влияние)",
    "Спроектировать контрольную процедуру",
    "Оценить эффективность существующего контроля",
    "Критически разобрать чужую оценку риска",
    "Сравнить подходы / фреймворки",
    "Предложить план митигации",
    "Проследить причинно-следственную цепочку риска"
]

axis_c = [
    "Планирование и оценка существенности",
    "Разработка программы тестов",
    "Оценка дефектов и документирование",
    "Ревью рабочей документации"
]

# База вопросов по категориям
questions_db = {
    ("Операционные риски процессов", "Объяснить концепцию/термин", "Планирование и оценка существенности"): 
        "На основе каких критериев вы разделяете операционные риски бизнес-процесса на «критичные» и «незначительные», и как величина финансового порога существенности влияет на границы периметра нашей проверки?",
    
    ("Операционные риски процессов", "Объяснить концепцию/термин", "Разработка программы тестов"): 
        "Каким образом в создаваемой программе тестов вы планируете разграничивать процедуры проверки дизайна контрольных процедур от процедур тестирования их фактической операционной эффективности?",
    
    ("Операционные риски процессов", "Объяснить концепцию/термин", "Оценка дефектов и документирование"): 
        "Чем принципиально отличается «отклонение» от «дефекта контроля» при документировании результатов проверки операционных процессов, и какие доказательства необходимы для каждой категории?",
    
    ("Операционные риски процессов", "Объяснить концепцию/термин", "Ревью рабочей документации"): 
        "При ревью чужой документации по операционным рискам на какие маркеры качества вы обращаете внимание в первую очередь, чтобы убедиться, что выводы обоснованы?",
    
    ("Операционные риски процессов", "Идентифицировать риски в сценарии", "Планирование и оценка существенности"): 
        "В процессе закупки сырья менеджер обходит тендерную процедуру, ссылаясь на срочность. Какие операционные риски вы заложите в план проверки и какой уровень существенности присвоите?",
    
    ("Операционные риски процессов", "Идентифицировать риски в сценарии", "Разработка программы тестов"): 
        "Производственный цех перешел на новую систему учета брака, но старые журналы ведутся параллельно. Какие тесты включите в программу для выявления расхождений между системами?",
    
    ("Операционные риски процессов", "Идентифицировать риски в сценарии", "Оценка дефектов и документирование"): 
        "Вы обнаружили, что складские остатки систематически не сверяются с данными ERP уже три квартала. Как классифицируете этот дефект и какие улики соберете для подтверждения масштаба проблемы?",
    
    ("Операционные риски процессов", "Идентифицировать риски в сценарии", "Ревью рабочей документации"): 
        "Младший аудитор выявил несоответствие в логистических процессах, но не указал корневую причину. Что вы потребуете доработать в его документации перед финальным отчетом?",
    
    ("Операционные риски процессов", "Оценить риск (вероятность × влияние)", "Планирование и оценка существенности"): 
        "Как вы определите пороговое значение аудиторского риска для процесса управления запасами, учитывая историческую частоту ошибок и потенциальный финансовый ущерб?",
    
    ("Операционные риски процессов", "Оценить риск (вероятность × влияние)", "Разработка программы тестов"): 
        "Процесс согласования договоров имеет высокий рейтинг риска из-за частых нарушений SLA. Какой объем выборки и метод отбора документов вы примените в программе тестов?",
    
    ("Операционные риски процессов", "Оценить риск (вероятность × влияние)", "Оценка дефектов и документирование"): 
        "Дефект в системе контроля качества привел к выпуску партии бракованной продукции на сумму 5 млн рублей. Как оцените совокупное влияние этого дефекта на операционные риски компании?",
    
    ("Операционные риски процессов", "Оценить риск (вероятность × влияние)", "Ревью рабочей документации"): 
        "В ревьюируемой работе коллега оценил вероятность сбоя в производственном процессе как «низкую», основываясь только на отсутствии инцидентов за последний месяц. Достаточно ли этого обоснования?",
    
    ("Операционные риски процессов", "Спроектировать контрольную процедуру", "Планирование и оценка существенности"): 
        "При планировании проверки процесса обработки заказов вы решили включить контроль автоматической верификации данных клиента. Как обоснуете существенность этого контроля для границ проверки?",
    
    ("Операционные риски процессов", "Спроектировать контрольную процедуру", "Разработка программы тестов"): 
        "Для минимизации ошибок при ручном вводе данных в систему учета вы проектируете контроль с двойной проверкой. Как опишете этот контроль в программе тестов и какие атрибуты укажете?",
    
    ("Операционные риски процессов", "Спроектировать контрольную процедуру", "Оценка дефектов и документирование"): 
        "Вы спроектировали превентивный контроль для исключения дублирования платежей, но он не был внедрен. Как задокументируете этот пробел и оцените его критичность?",
    
    ("Операционные риски процессов", "Спроектировать контрольную процедуру", "Ревью рабочей документации"): 
        "При ревью вы видите, что предложенный контроль для операционного процесса слишком сложен и требует участия пяти сотрудников. Какие рекомендации дадите по оптимизации?",
    
    ("Операционные риски процессов", "Оценить эффективность существующего контроля", "Планирование и оценка существенности"): 
        "Существующий контроль ежемесячной сверки остатков считается эффективным, но за год выявлено 12 случаев расхождений. Пересмотрите ли вы оценку существенности этого процесса?",
    
    ("Операционные риски процессов", "Оценить эффективность существующего контроля", "Разработка программы тестов"): 
        "Контроль подписания актов выполненных работ формально существует, но 30% актов подписаны задним числом. Как адаптируете программу тестов для оценки реальной эффективности этого контроля?",
    
    ("Операционные риски процессов", "Оценить эффективность существующего контроля", "Оценка дефектов и документирование"): 
        "Автоматический контроль блокировки превышения лимита расходов обходится через временное увеличение бюджета без надлежащего согласования. Как классифицируете этот дефект эффективности?",
    
    ("Операционные риски процессов", "Оценить эффективность существующего контроля", "Ревью рабочей документации"): 
        "В документации указано, что контроль еженедельного мониторинга KPI эффективен, но нет доказательств анализа отклонений. Примете ли вы такую оценку или запросите дополнительные материалы?",
    
    ("Операционные риски процессов", "Критически разобрать чужую оценку риска", "Планирование и оценка существенности"): 
        "Коллега определил процесс инвентаризации как низкорисковый, игнорируя недавние случаи хищений на складах. Как аргументированно оспорите эту оценку при планировании проверки?",
    
    ("Операционные риски процессов", "Критически разобрать чужую оценку риска", "Разработка программы тестов"): 
        "В предложенной программе тестов упор сделан на детальные проверки транзакций, хотя риск системных сбоев выше. Как скорректируете подход к выбору методов тестирования?",
    
    ("Операционные риски процессов", "Критически разобрать чужую оценку риска", "Оценка дефектов и документирование"): 
        "Другой аудитор классифицировал отсутствие резервного копирования операционных данных как «незначительный дефект». Разделите ли вы эту точку зрения и почему?",
    
    ("Операционные риски процессов", "Критически разобрать чужую оценку риска", "Ревью рабочей документации"): 
        "При ревью вы обнаружили, что выводы о низком уровне операционных рисков сделаны на основе интервью без проверки документов. Какие замечания внесете в рабочую документацию?",
    
    ("Операционные риски процессов", "Сравнить подходы / фреймворки", "Планирование и оценка существенности"): 
        "При оценке существенности операционных рисков вы можете использовать подход на основе материальности или подход на основе критичности процессов. В каких случаях каждый из них предпочтительнее?",
    
    ("Операционные риски процессов", "Сравнить подходы / фреймворки", "Разработка программы тестов"): 
        "Для тестирования операционных контролей можно применить статистическую выборку или целевой отбор. Когда вы выберете каждый метод и как это повлияет на дизайн программы тестов?",
    
    ("Операционные риски процессов", "Сравнить подходы / фреймворки", "Оценка дефектов и документирование"): 
        "Сравните подходы COSO и ISO 31000 к классификации дефектов операционных контролей. Какой фреймворк лучше подходит для нашего внутреннего аудита и почему?",
    
    ("Операционные риски процессов", "Сравнить подходы / фреймворки", "Ревью рабочей документации"): 
        "Один аудитор использует матрицу рисков 3×3, другой — 5×5 при документировании операционных рисков. Какой подход обеспечит более качественную документацию для ревью?",
    
    ("Операционные риски процессов", "Предложить план митигации", "Планирование и оценка существенности"): 
        "Выявлен систематический срыв сроков выполнения заказов клиентами. Предложите план митигации и обоснуйте, почему эти меры должны войти в приоритетный периметр следующей проверки.",
    
    ("Операционные риски процессов", "Предложить план митигации", "Разработка программы тестов"): 
        "Для снижения риска ошибок в расчетах с контрагентами вы предлагаете внедрить автоматическую сверку. Как интегрируете тестирование этого решения в программу будущих проверок?",
    
    ("Операционные риски процессов", "Предложить план митигации", "Оценка дефектов и документирование"): 
        "Обнаружен дефект: отсутствие ротации сотрудников на критичных участках производства. Предложите меры митигации и опишите, как зафиксируете их реализацию в документации.",
    
    ("Операционные риски процессов", "Предложить план митигации", "Ревью рабочей документации"): 
        "В ревьюируемом отчете предложен план митигации операционных рисков, но без четких сроков и ответственных. Какие требования предъявите к доработке рекомендаций?",
    
    ("Операционные риски процессов", "Проследить причинно-следственную цепочку риска", "Планирование и оценка существенности"): 
        "Отсутствие обучения операторов привело к росту брака, что вызвало штрафы от клиентов и потерю контрактов. Как эта цепочка повлияет на ваше решение о существенности процесса обучения?",
    
    ("Операционные риски процессов", "Проследить причинно-следственную цепочку риска", "Разработка программы тестов"): 
        "Сбой в системе учета материалов → неверные данные о запасах → закупка излишков → замораживание оборотных средств. Какие точки этой цепочки включите в программу тестов?",
    
    ("Операционные риски процессов", "Проследить причинно-следственную цепочку риска", "Оценка дефектов и документирование"): 
        "Неавторизованный доступ к системе управления производством привел к изменению рецептур и массовому браку. Как проследите и задокументируете всю цепочку от доступа до финансовых потерь?",
    
    ("Операционные риски процессов", "Проследить причинно-следственную цепочку риска", "Ревью рабочей документации"): 
        "В документации описан дефект контроля качества, но не показана связь с последующими рекламациями клиентов. Что потребуете добавить для полноты картины?",
}

# Продолжаем генерацию для остальных категорий...
# Проектные риски
project_risks_questions = {
    ("Проектные риски (бизнес-проекты)", "Объяснить концепцию/термин", "Планирование и оценка существенности"): 
        "Что такое «рискscope creep» в контексте бизнес-проектов и как его потенциальное влияние учитывается при определении границ аудиторской проверки проекта?",
    
    ("Проектные риски (бизнес-проекты)", "Объяснить концепцию/термин", "Разработка программы тестов"): 
        "Объясните разницу между контролем управления изменениями проекта и контролем управления бюджетом. Как отразите эту разницу в дизайне тестовых процедур?",
    
    ("Проектные риски (бизнес-проекты)", "Объяснить концепцию/термин", "Оценка дефектов и документирование"): 
        "Чем отличается «отклонение от плана проекта» от «дефекта проектного управления» при документировании результатов проверки?",
    
    ("Проектные риски (бизнес-проекты)", "Объяснить концепцию/термин", "Ревью рабочей документации"): 
        "На какие ключевые элементы проектной документации вы обращаете внимание при ревью, чтобы убедиться в полноте оценки проектных рисков?",
    
    ("Проектные риски (бизнес-проекты)", "Идентифицировать риски в сценарии", "Планирование и оценка существенности"): 
        "IT-проект по внедрению CRM отстает от графика на 4 месяца, бюджет превышен на 60%. Какие проектные риски заложите в план проверки и каков будет уровень существенности?",
    
    ("Проектные риски (бизнес-проекты)", "Идентифицировать риски в сценарии", "Разработка программы тестов"): 
        "В проекте строительства нового офиса подрядчик сменился дважды, документация по этапам неполная. Какие тесты включите для проверки управления этим проектом?",
    
    ("Проектные риски (бизнес-проекты)", "Идентифицировать риски в сценарии", "Оценка дефектов и документирование"): 
        "Руководитель проекта самостоятельно утвердил изменение технических требований без согласования с заказчиком. Как классифицируете этот дефект и какие доказательства соберете?",
    
    ("Проектные риски (бизнес-проекты)", "Идентифицировать риски в сценарии", "Ревью рабочей документации"): 
        "Младший аудитор выявил риски в проекте цифровизации, но не оценил их влияние на стратегические цели компании. Что добавите в его документацию?",
    
    ("Проектные риски (бизнес-проекты)", "Оценить риск (вероятность × влияние)", "Планирование и оценка существенности"): 
        "Как определите аудиторский риск для проекта с высокой неопределенностью технологий, но низким финансовым объемом инвестиций?",
    
    ("Проектные риски (бизнес-проекты)", "Оценить риск (вероятность × влияние)", "Разработка программы тестов"): 
        "Проект имеет высокий риск срыва сроков из-за зависимости от единственного поставщика. Какой объем выборки документов по управлению поставщиками включите в программу?",
    
    ("Проектные риски (бизнес-проекты)", "Оценить риск (вероятность × влияние)", "Оценка дефектов и документирование"): 
        "Отсутствие регулярного статус-мониторинга привело к обнаружению проблем на поздней стадии проекта стоимостью 50 млн руб. Как оцените совокупное влияние этого дефекта?",
    
    ("Проектные риски (бизнес-проекты)", "Оценить риск (вероятность × влияние)", "Ревью рабочей документации"): 
        "Коллега оценил вероятность провала проекта как «среднюю», основываясь только на мнении руководителя проекта. Достаточно ли такого обоснования для ревью?",
    
    ("Проектные риски (бизнес-проекты)", "Спроектировать контрольную процедуру", "Планирование и оценка существенности"): 
        "При планировании проверки крупного инфраструктурного проекта вы хотите включить контроль ежеквартального независимого аудита прогресса. Как обоснуете существенность этого контроля?",
    
    ("Проектные риски (бизнес-проекты)", "Спроектировать контрольную процедуру", "Разработка программы тестов"): 
        "Для контроля соблюдения этапов проекта вы проектируете процедуру обязательного gate-review перед переходом на следующую фазу. Как опишете этот контроль в программе тестов?",
    
    ("Проектные риски (бизнес-проекты)", "Спроектировать контрольную процедуру", "Оценка дефектов и документирование"): 
        "Вы предложили контроль обязательного согласования изменений бюджета свыше 10%, но он не внедрен. Как задокументируете этот пробел в проектном управлении?",
    
    ("Проектные риски (бизнес-проекты)", "Спроектировать контрольную процедуру", "Ревью рабочей документации"): 
        "При ревью видите, что предложенный контроль для проекта требует ежемесячных отчетов от 15 участников. Какие рекомендации дадите по упрощению без потери эффективности?",
    
    ("Проектные риски (бизнес-проекты)", "Оценить эффективность существующего контроля", "Планирование и оценка существенности"): 
        "Контроль еженедельных совещаний по проекту формально проводится, но решения не фиксируются. Пересмотрите ли вы оценку существенности проектных рисков?",
    
    ("Проектные риски (бизнес-проекты)", "Оценить эффективность существующего контроля", "Разработка программы тестов"): 
        "Система управления проектами требует обновления статусов, но 40% задач обновляются постфактум. Как адаптируете программу тестов для оценки реальной дисциплины ведения проекта?",
    
    ("Проектные риски (бизнес-проекты)", "Оценить эффективность существующего контроля", "Оценка дефектов и документирование"): 
        "Контроль утверждения изменений scope обходится через разбиение крупных изменений на мелкие части. Как классифицируете этот дефект эффективности проектного контроля?",
    
    ("Проектные риски (бизнес-проекты)", "Оценить эффективность существующего контроля", "Ревью рабочей документации"): 
        "В документации заявлена эффективность контроля управления рисками проекта, но нет evidence проведения регулярных risk review meetings. Примете ли такую оценку?",
    
    ("Проектные риски (бизнес-проекты)", "Критически разобрать чужую оценку риска", "Планирование и оценка существенности"): 
        "Коллега считает проект низкоприоритетным для аудита, так как он «технический». Как оспорите эту оценку, учитывая стратегическую важность цифровой трансформации?",
    
    ("Проектные риски (бизнес-проекты)", "Критически разобрать чужую оценку риска", "Разработка программы тестов"): 
        "В программе тестов акцент сделан на финансовую отчетность проекта, хотя основные риски связаны с качеством deliverables. Как скорректируете подход?",
    
    ("Проектные риски (бизнес-проекты)", "Критически разобрать чужую оценку риска", "Оценка дефектов и документирование"): 
        "Другой аудитор назвал отсутствие lessons learned по завершении проекта «рекомендацией к улучшению», а не дефектом. Согласны ли вы с такой классификацией?",
    
    ("Проектные риски (бизнес-проекты)", "Критически разобрать чужую оценку риска", "Ревью рабочей документации"): 
        "При ревью обнаружили, что выводы о низких проектных рисках основаны только на статусах от PM, без независимой проверки. Какие замечания внесете?",
    
    ("Проектные риски (бизнес-проекты)", "Сравнить подходы / фреймворки", "Планирование и оценка существенности"): 
        "Сравните подходы PMI и PRINCE2 к оценке существенности проектных рисков. Какой фреймворк лучше интегрируется с нашим внутренним аудитом?",
    
    ("Проектные риски (бизнес-проекты)", "Сравнить подходы / фреймворки", "Разработка программы тестов"): 
        "Для тестирования проектных контролей можно использовать agile-подход или waterfall-методологию проверки. Когда применим каждый и как это повлияет на программу?",
    
    ("Проектные риски (бизнес-проекты)", "Сравнить подходы / фреймворки", "Оценка дефектов и документирование"): 
        "Сравните классификацию дефектов в PMBOK и ISO 21500. Какой стандарт даст более структурированную документацию для нашего аудита проектов?",
    
    ("Проектные риски (бизнес-проекты)", "Сравнить подходы / фреймворки", "Ревью рабочей документации"): 
        "Один аудитор документирует проектные риски через register рисков, другой — через heat map. Какой формат обеспечит лучшее качество для ревью?",
    
    ("Проектные риски (бизнес-проекты)", "Предложить план митигации", "Планирование и оценка существенности"): 
        "Выявлена высокая текучесть ключевых специалистов проекта. Предложите план митигации и обоснуйте включение HR-процессов в периметр аудита проектов.",
    
    ("Проектные риски (бизнес-проекты)", "Предложить план митигации", "Разработка программы тестов"): 
        "Для снижения риска срыва сроков вы предлагаете внедрить buffer management. Как протестируете эффективность этого механизма в будущих проверках?",
    
    ("Проектные риски (бизнес-проекты)", "Предложить план митигации", "Оценка дефектов и документирование"): 
        "Обнаружен дефект: отсутствие резервного плана на случай ухода ключевого подрядчика. Предложите меры митигации и опишите их фиксацию в документации.",
    
    ("Проектные риски (бизнес-проекты)", "Предложить план митигации", "Ревью рабочей документации"): 
        "В ревьюируемом плане митигации проектных рисков нет метрик успеха. Какие требования предъявите к количественной оценке эффективности предлагаемых мер?",
    
    ("Проектные риски (бизнес-проекты)", "Проследить причинно-следственную цепочку риска", "Планирование и оценка существенности"): 
        "Недостаточное тестирование → баги в продукте → задержка запуска → потеря рыночной доли. Как эта цепочка повлияет на оценку существенности этапа QA в проекте?",
    
    ("Проектные риски (бизнес-проекты)", "Проследить причинно-следственную цепочку риска", "Разработка программы тестов"): 
        "Слабая коммуникация с заказчиком → неверное понимание требований → переделки → превышение бюджета. Какие звенья этой цепочки включите в программу тестов?",
    
    ("Проектные риски (бизнес-проекты)", "Проследить причинно-следственную цепочку риска", "Оценка дефектов и документирование"): 
        "Отсутствие formal change control привело к неконтролируемому расширению scope, затем к срыву сроков и штрафам. Как проследите и задокументируете эту цепочку?",
    
    ("Проектные риски (бизнес-проекты)", "Проследить причинно-следственную цепочку риска", "Ревью рабочей документации"): 
        "В документации описан дефект управления ресурсами проекта, но не показана связь с итоговой задержкой сдачи. Что потребуете добавить?",
}

# Комплианс и регуляторные риски
compliance_questions = {
    ("Комплаенс и регуляторные риски", "Объяснить концепцию/термин", "Планирование и оценка существенности"): 
        "Что такое «регуляторный риск второго порядка» и как его косвенное влияние учитывается при определении существенности комплаенс-проверки?",
    
    ("Комплаенс и регуляторные риски", "Объяснить концепцию/термин", "Разработка программы тестов"): 
        "Объясните разницу между превентивным и детективным комплаенс-контролем. Как эта разница повлияет на выбор методов тестирования в программе?",
    
    ("Комплаенс и регуляторные риски", "Объяснить концепцию/термин", "Оценка дефектов и документирование"): 
        "Чем отличается «несоблюдение требования» от «системного комплаенс-дефекта» при документировании результатов проверки?",
    
    ("Комплаенс и регуляторные риски", "Объяснить концепцию/термин", "Ревью рабочей документации"): 
        "На какие регуляторные ссылки и нормативные акты вы обращаете внимание при ревью комплаенс-документации, чтобы убедиться в корректности выводов?",
    
    ("Комплаенс и регуляторные риски", "Идентифицировать риски в сценарии", "Планирование и оценка существенности"): 
        "Компания начала работу с персональными данными клиентов без назначения DPO. Какие регуляторные риски заложите в план и каков уровень существенности с учетом штрафов по 152-ФЗ?",
    
    ("Комплаенс и регуляторные риски", "Идентифицировать риски в сценарии", "Разработка программы тестов"): 
        "Бухгалтерия применяет новые требования ФСБУ, но инструкций для сотрудников нет. Какие тесты включите для проверки готовности к регуляторным изменениям?",
    
    ("Комплаенс и регуляторные риски", "Идентифицировать риски в сценарии", "Оценка дефектов и документирование"): 
        "Выявлено, что компания не подает отчетность в Росстат уже два квартала. Как классифицируете этот дефект и какие улики соберете для подтверждения системности нарушения?",
    
    ("Комплаенс и регуляторные риски", "Идентифицировать риски в сценарии", "Ревью рабочей документации"): 
        "Младший аудитор нашел нарушения антимонопольного законодательства, но не оценил репутационные последствия. Что добавите в его документацию?",
    
    ("Комплаенс и регуляторные риски", "Оценить риск (вероятность × влияние)", "Планирование и оценка существенности"): 
        "Как определите аудиторский риск для области, где регуляторные требования часто меняются, но исторически нарушений не было?",
    
    ("Комплаенс и регуляторные риски", "Оценить риск (вероятность × влияние)", "Разработка программы тестов"): 
        "Риск штрафов за нарушение валютного законодательства оценен как высокий из-за роста внешнеэкономической деятельности. Какой объем выборки внешнеторговых контрактов включите в программу?",
    
    ("Комплаенс и регуляторные риски", "Оценить риск (вероятность × влияние)", "Оценка дефектов и документирование"): 
        "Отсутствие лицензий на отдельные виды деятельности привело к приостановке операций и убыткам 20 млн руб. Как оцените совокупное влияние этого комплаенс-дефекта?",
    
    ("Комплаенс и регуляторные риски", "Оценить риск (вероятность × влияние)", "Ревью рабочей документации"): 
        "Коллега оценил вероятность регуляторной проверки как «низкую», потому что «нас давно не проверяли». Достаточно ли такого обоснования для ревью?",
    
    ("Комплаенс и регуляторные риски", "Спроектировать контрольную процедуру", "Планирование и оценка существенности"): 
        "При планировании проверки вы хотите включить контроль ежеквартального мониторинга изменений законодательства. Как обоснуете существенность этого контроля для комплаенс-рисков?",
    
    ("Комплаенс и регуляторные риски", "Спроектировать контрольную процедуру", "Разработка программы тестов"): 
        "Для обеспечения соблюдения трудового законодательства вы проектируете контроль автоматической проверки трудовых договоров. Как опишете этот контроль в программе тестов?",
    
    ("Комплаенс и регуляторные риски", "Спроектировать контрольную процедуру", "Оценка дефектов и документирование"): 
        "Вы предложили контроль обязательного согласования договоров с юристами, но он не внедрен. Как задокументируете этот комплаенс-пробел?",
    
    ("Комплаенс и регуляторные риски", "Спроектировать контрольную процедуру", "Ревью рабочей документации"): 
        "При ревью видите, что предложенный комплаенс-контроль требует ежемесячного анализа 200+ нормативных актов. Какие рекомендации дадите по фокусировке на материальных требованиях?",
    
    ("Комплаенс и регуляторные риски", "Оценить эффективность существующего контроля", "Планирование и оценка существенности"): 
        "Контроль ежегодного обучения по комплаенс формально проводится, но тестирование знаний отсутствует. Пересмотрите ли вы оценку существенности комплаенс-рисков?",
    
    ("Комплаенс и регуляторные риски", "Оценить эффективность существующего контроля", "Разработка программы тестов"): 
        "Система комплаенс-мониторинга требует декларирования конфликтов интересов, но 60% сотрудников не подали декларации. Как адаптируете программу тестов?",
    
    ("Комплаенс и регуляторные риски", "Оценить эффективность существующего контроля", "Оценка дефектов и документирование"): 
        "Контроль проверки контрагентов на санкции обходится через использование посредников. Как классифицируете этот дефект эффективности комплаенс-контроля?",
    
    ("Комплаенс и регуляторные риски", "Оценить эффективность существующего контроля", "Ревью рабочей документации"): 
        "В документации заявлена эффективность контроля regulatory reporting, но нет evidence своевременности подачи последних 5 отчетов. Примете ли такую оценку?",
    
    ("Комплаенс и регуляторные риски", "Критически разобрать чужую оценку риска", "Планирование и оценка существенности"): 
        "Коллега исключил из плана проверку экологического комплаенса, считая отрасль «негрязной». Как оспорите эту оценку с учетом ужесточения природоохранного законодательства?",
    
    ("Комплаенс и регуляторные риски", "Критически разобрать чужую оценку риска", "Разработка программы тестов"): 
        "В программе тестов упор на налоговые риски, хотя основные претензии регуляторов касаются защиты персональных данных. Как скорректируете баланс?",
    
    ("Комплаенс и регуляторные риски", "Критически разобрать чужую оценку риска", "Оценка дефектов и документирование"): 
        "Другой аудитор назвал отсутствие политики whistleblowing «лучшей практикой», а не дефектом. Разделите ли вы эту точку зрения в свете требований ЦБ РФ?",
    
    ("Комплаенс и регуляторные риски", "Критически разобрать чужую оценку риска", "Ревью рабочей документации"): 
        "При ревью обнаружили, что выводы о низких комплаенс-рисках основаны только на заверениях compliance-офицера. Какие замечания внесете?",
    
    ("Комплаенс и регуляторные риски", "Сравнить подходы / фреймворки", "Планирование и оценка существенности"): 
        "Сравните подходы к оценке существенности комплаенс-рисков в стандартах IIA и требованиях Банка России. Какой подход приоритетнее для нашей компании?",
    
    ("Комплаенс и регуляторные риски", "Сравнить подходы / фреймворки", "Разработка программы тестов"): 
        "Для тестирования комплаенс-контролей можно использовать check-list подход или risk-based sampling. Когда применим каждый метод и как это отразится на программе?",
    
    ("Комплаенс и регуляторные риски", "Сравнить подходы / фреймворки", "Оценка дефектов и документирование"): 
        "Сравните классификацию комплаенс-нарушений по GDPR и 152-ФЗ. Какой стандарт даст более релевантную структуру для нашего документирования?",
    
    ("Комплаенс и регуляторные риски", "Сравнить подходы / фреймворки", "Ревью рабочей документации"): 
        "Один аудитор документирует комплаенс-риски через матрицу соответствия, другой — через narrative. Какой формат обеспечит лучшее качество для ревью?",
    
    ("Комплаенс и регуляторные риски", "Предложить план митигации", "Планирование и оценка существенности"): 
        "Выявлены систематические нарушения сроков сдачи налоговой отчетности. Предложите план митигации и обоснуйте включение налогового комплаенса в приоритетный периметр.",
    
    ("Комплаенс и регуляторные риски", "Предложить план митигации", "Разработка программы тестов"): 
        "Для снижения риска нарушений ПДн вы предлагаете внедрить automated consent management. Как протестируете эффективность этого механизма в будущих проверках?",
    
    ("Комплаенс и регуляторные риски", "Предложить план митигации", "Оценка дефектов и документирование"): 
        "Обнаружен дефект: отсутствие процедуры уведомления регулятора об инцидентах ПДн. Предложите меры митигации и опишите их фиксацию в документации.",
    
    ("Комплаенс и регуляторные риски", "Предложить план митигации", "Ревью рабочей документации"): 
        "В ревьюируемом плане митигации комплаенс-рисков нет оценки стоимости внедрения контролей. Какие требования предъявите к cost-benefit анализу?",
    
    ("Комплаенс и регуляторные риски", "Проследить причинно-следственную цепочку риска", "Планирование и оценка существенности"): 
        "Отсутствие обучения по антикоррупционному комплаенсу → взятка сотрудником → уголовное дело → репутационный ущерб. Как эта цепочка повлияет на оценку существенности training-программ?",
    
    ("Комплаенс и регуляторные риски", "Проследить причинно-следственную цепочку риска", "Разработка программы тестов"): 
        "Неполная проверка контрагентов → работа с санкционным лицом → блокировка счетов → остановка операций. Какие звенья этой цепочки включите в программу тестов?",
    
    ("Комплаенс и регуляторные риски", "Проследить причинно-следственную цепочку риска", "Оценка дефектов и документирования"): 
        "Нарушение сроков подачи отчетности в ФНС → начисление пеней → налоговая проверка → доначисления. Как проследите и задокументируете эту цепочку?",
    
    ("Комплаенс и регуляторные риски", "Проследить причинно-следственную цепочку риска", "Ревью рабочей документации"): 
        "В документации описан комплаенс-дефект, но не показана связь с потенциальными штрафами. Что потребуете добавить для оценки материальности?",
}

print(f"Сгенерировано вопросов на данный момент: {len(questions_db) + len(project_risks_questions) + len(compliance_questions)}")
# Out:
# Сгенерировано вопросов на данный момент: 108

# %%
# Финансовые риски и риски отчётности
financial_risks_questions = {
    ("Финансовые риски и риски отчётности", "Объяснить концепцию/термин", "Планирование и оценка существенности"): 
        "Что такое «риск существенного искажения» в финансовой отчетности и как он влияет на определение materiality threshold при планировании аудита?",
    
    ("Финансовые риски и риски отчётности", "Объяснить концепцию/термин", "Разработка программы тестов"): 
        "Объясните разницу между субстантивными процедурами и тестами контролей в контексте проверки финансовой отчетности. Как сбалансировать их в программе тестов?",
    
    ("Финансовые риски и риски отчётности", "Объяснить концепцию/термин", "Оценка дефектов и документирование"): 
        "Чем отличается «ошибка в расчетах» от «дефекта контроля финансовой отчетности» при документировании результатов проверки?",
    
    ("Финансовые риски и риски отчётности", "Объяснить концепцию/термин", "Ревью рабочей документации"): 
        "На какие элементы аудиторских доказательств вы обращаете внимание при ревью документации по финансовым рискам, чтобы убедиться в достаточности evidence?",
    
    ("Финансовые риски и риски отчётности", "Идентифицировать риски в сценарии", "Планирование и оценка существенности"): 
        "Компания изменила метод амортизации основных средств без раскрытия в примечаниях. Какие финансовые риски заложите в план и каков уровень существенности?",
    
    ("Финансовые риски и риски отчётности", "Идентифицировать риски в сценарии", "Разработка программы тестов"): 
        "Выявлены расхождения между данными управленческого и бухгалтерского учета по выручке. Какие тесты включите для проверки полноты и точности отражения доходов?",
    
    ("Финансовые риски и риски отчётности", "Идентифицировать риски в сценарии", "Оценка дефектов и документирование"): 
        "Обнаружено, что резерв по сомнительным долгам не пересматривался 6 месяцев при росте просрочки. Как классифицируете этот дефект и какие улики соберете?",
    
    ("Финансовые риски и риски отчётности", "Идентифицировать риски в сценарии", "Ревью рабочей документации"): 
        "Младший аудитор выявил ошибки в консолидации, но не оценил влияние на ключевые финансовые коэффициенты. Что добавите в его документацию?",
    
    ("Финансовые риски и риски отчётности", "Оценить риск (вероятность × влияние)", "Планирование и оценка существенности"): 
        "Как определите аудиторский риск для статьи «дебиторская задолженность», учитывая высокую долю просроченной задолженности и нестабильность контрагентов?",
    
    ("Финансовые риски и риски отчётности", "Оценить риск (вероятность × влияние)", "Разработка программы тестов"): 
        "Риск искажения запасов оценен как высокий из-за сложной методики оценки НЗП. Какой объем выборки и методы тестирования включите в программу?",
    
    ("Финансовые риски и риски отчётности", "Оценить риск (вероятность × влияние)", "Оценка дефектов и документирование"): 
        "Неправильное применение ФСБУ 25/2018 привело к занижению обязательств на 15 млн руб. Как оцените совокупное влияние этого дефекта на достоверность отчетности?",
    
    ("Финансовые риски и риски отчётности", "Оценить риск (вероятность × влияние)", "Ревью рабочей документации"): 
        "Коллега оценил вероятность ошибок в расчете налога на прибыль как «низкую», основываясь только на отсутствии претензий ФНС. Достаточно ли этого для ревью?",
    
    ("Финансовые риски и риски отчётности", "Спроектировать контрольную процедуру", "Планирование и оценка существенности"): 
        "При планировании проверки вы хотите включить контроль ежемесячного анализа колебаний毛利率 по продуктовым линейкам. Как обоснуете существенность этого аналитического контроля?",
    
    ("Финансовые риски и риски отчётности", "Спроектировать контрольную процедуру", "Разработка программы тестов"): 
        "Для обеспечения точности расчетов с бюджетом вы проектируете контроль автоматической сверки данных налогового учета с бухгалтерским. Как опишете этот контроль в программе?",
    
    ("Финансовые риски и риски отчётности", "Спроектировать контрольную процедуру", "Оценка дефектов и документирование"): 
        "Вы предложили контроль обязательного визирования CFO всех проводок свыше 1 млн руб., но он не внедрен. Как задокументируете этот пробел в финансовом контроле?",
    
    ("Финансовые риски и риски отчётности", "Спроектировать контрольную процедуру", "Ревью рабочей документации"): 
        "При ревью видите, что предложенный контроль требует ручного согласования 500+ платежей ежемесячно. Какие рекомендации дадите по автоматизации без потери контроля?",
    
    ("Финансовые риски и риски отчётности", "Оценить эффективность существующего контроля", "Планирование и оценка существенности"): 
        "Контроль ежемесячного закрытия периода формально соблюдается, но корректирующие проводки вносятся массово post-close. Пересмотрите ли вы оценку рисков отчетности?",
    
    ("Финансовые риски и риски отчётности", "Оценить эффективность существующего контроля", "Разработка программы тестов"): 
        "Система разделения обязанностей в бухгалтерии существует, но один сотрудник имеет доступ к созданию и утверждению платежей. Как адаптируете программу тестов?",
    
    ("Финансовые риски и риски отчётности", "Оценить эффективность существующего контроля", "Оценка дефектов и документирование"): 
        "Контроль инвентаризации ТМЦ обходится через использование «условных» остатков без физического подсчета. Как классифицируете этот дефект эффективности?",
    
    ("Финансовые риски и риски отчётности", "Оценить эффективность существующего контроля", "Ревью рабочей документации"): 
        "В документации заявлена эффективность контроля accruals, но нет evidence анализа значимых начислений на предмет полноты. Примете ли такую оценку?",
    
    ("Финансовые риски и риски отчётности", "Критически разобрать чужую оценку риска", "Планирование и оценка существенности"): 
        "Коллега исключил из плана проверку валютных операций, считая хеджирование эффективным. Как оспорите эту оценку с учетом волатильности курса рубля?",
    
    ("Финансовые риски и риски отчётности", "Критически разобрать чужую оценку риска", "Разработка программы тестов"): 
        "В программе тестов упор на проверку основных средств, хотя основные риски искажений связаны с оценкой гудвила. Как скорректируете баланс?",
    
    ("Финансовые риски и риски отчётности", "Критически разобрать чужую оценку риска", "Оценка дефектов и документирование"): 
        "Другой аудитор назвал отсутствие политики hedge accounting «незначительным замечанием». Разделите ли вы эту точку зрения с учетом требований МСФО 9?",
    
    ("Финансовые риски и риски отчётности", "Критически разобрать чужую оценку риска", "Ревью рабочей документации"): 
        "При ревью обнаружили, что выводы о низких финансовых рисках основаны только на заверениях главного бухгалтера. Какие замечания внесете?",
    
    ("Финансовые риски и риски отчётности", "Сравнить подходы / фреймворки", "Планирование и оценка существенности"): 
        "Сравните подходы к оценке materiality в ISA и российских стандартах аудита. Какой подход более консервативен для нашего внутреннего аудита?",
    
    ("Финансовые риски и риски отчётности", "Сравнить подходы / фреймворки", "Разработка программы тестов"): 
        "Для тестирования финансовых контролей можно использовать substantive analytical procedures или tests of details. Когда применим каждый метод и как это отразится на программе?",
    
    ("Финансовые риски и риски отчётности", "Сравнить подходы / фреймворки", "Оценка дефектов и документирование"): 
        "Сравните классификацию ошибок по РСБУ и МСФО. Какой стандарт даст более релевантную структуру для документирования дефектов финансовой отчетности?",
    
    ("Финансовые риски и риски отчётности", "Сравнить подходы / фреймворки", "Ревью рабочей документации"): 
        "Один аудитор документирует финансовые риски через flowchart процессов, другой — через risk control matrix. Какой формат обеспечит лучшее качество для ревью?",
    
    ("Финансовые риски и риски отчётности", "Предложить план митигации", "Планирование и оценка существенности"): 
        "Выявлены систематические ошибки в расчете себестоимости продукции. Предложите план митигации и обоснуйте включение cost accounting в приоритетный периметр.",
    
    ("Финансовые риски и риски отчётности", "Предложить план митигации", "Разработка программы тестов"): 
        "Для снижения риска ошибок в консолидации вы предлагаете внедрить automated reconciliation tool. Как протестируете эффективность этого инструмента в будущих проверках?",
    
    ("Финансовые риски и риски отчётности", "Предложить план митигации", "Оценка дефектов и документирование"): 
        "Обнаружен дефект: отсутствие monthly review значимых статей баланса CFO. Предложите меры митигации и опишите их фиксацию в документации.",
    
    ("Финансовые риски и риски отчётности", "Предложить план митигации", "Ревью рабочей документации"): 
        "В ревьюируемом плане митигации финансовых рисков нет timeline внедрения контролей. Какие требования предъявите к реалистичности сроков?",
    
    ("Финансовые риски и риски отчётности", "Проследить причинно-следственную цепочку риска", "Планирование и оценка существенности"): 
        "Отсутствие контроля цен закупки → завышение себестоимости → снижение маржинальности → неверные управленческие решения. Как эта цепочка повлияет на оценку существенности procurement?",
    
    ("Финансовые риски и риски отчётности", "Проследить причинно-следственную цепочку риска", "Разработка программы тестов"): 
        "Ошибки в учете основных средств → неверная амортизация → искажение прибыли → неправильный расчет налога. Какие звенья этой цепочки включите в программу тестов?",
    
    ("Финансовые риски и риски отчётности", "Проследить причинно-следственную цепочку риска", "Оценка дефектов и документирование"): 
        "Неполное отражение обязательств по аренде → занижение долговой нагрузки → нарушение ковенантов → штрафы банка. Как проследите и задокументируете эту цепочку?",
    
    ("Финансовые риски и риски отчётности", "Проследить причинно-следственную цепочку риска", "Ревью рабочей документации"): 
        "В документации описан дефект учета выручки, но не показана связь с искажением EBITDA. Что потребуете добавить для оценки влияния на KPI?",
}

# ИТ- и киберриски
it_cyber_questions = {
    ("ИТ- и киберриски", "Объяснить концепцию/термин", "Планирование и оценка существенности"): 
        "Что такое «риск неприменимости патчей безопасности» и как он учитывается при определении границ аудиторской проверки ИТ-инфраструктуры?",
    
    ("ИТ- и киберриски", "Объяснить концепцию/термин", "Разработка программы тестов"): 
        "Объясните разницу между vulnerability assessment и penetration testing. Как эта разница повлияет на дизайн тестовых процедур в программе?",
    
    ("ИТ- и киберриски", "Объяснить концепцию/термин", "Оценка дефектов и документирование"): 
        "Чем отличается «уязвимость системы» от «дефекта ИТ-контроля» при документировании результатов кибербезопасности?",
    
    ("ИТ- и киберриски", "Объяснить концепцию/термин", "Ревью рабочей документации"): 
        "На какие технические артефакты (логи, конфигурации, отчеты сканеров) вы обращаете внимание при ревью ИТ-документации для подтверждения выводов?",
    
    ("ИТ- и киберриски", "Идентифицировать риски в сценарии", "Планирование и оценка существенности"): 
        "Администраторы имеют shared accounts для доступа к продуктивной базе данных. Какие киберриски заложите в план и каков уровень существенности с учетом риска утечки ПДн?",
    
    ("ИТ- и киберриски", "Идентифицировать риски в сценарии", "Разработка программы тестов"): 
        "Резервное копирование выполняется, но тесты восстановления не проводились год. Какие тесты включите для проверки готовности к инцидентам?",
    
    ("ИТ- и киберриски", "Идентифицировать риски в сценарии", "Оценка дефектов и документирование"): 
        "Обнаружено, что критичные серверы работают на неподдерживаемых ОС без compensating controls. Как классифицируете этот дефект и какие улики соберете?",
    
    ("ИТ- и киберриски", "Идентифицировать риски в сценарии", "Ревью рабочей документации"): 
        "Младший аудитор выявил слабые пароли, но не оценил риск lateral movement в случае компрометации. Что добавите в его документацию?",
    
    ("ИТ- и киберриски", "Оценить риск (вероятность × влияние)", "Планирование и оценка существенности"): 
        "Как определите аудиторский риск для ИТ-системы, обрабатывающей ПДн, учитывая частоту кибератак в отрасли и стоимость потенциального breach?",
    
    ("ИТ- и киберриски", "Оценить риск (вероятность × влияние)", "Разработка программы тестов"): 
        "Риск несанкционированного доступа оценен как высокий из-за отсутствия MFA. Какой объем выборки учетных записей и методов тестирования включите в программу?",
    
    ("ИТ- и киберриски", "Оценить риск (вероятность × влияние)", "Оценка дефектов и документирование"): 
        "Отсутствие сегментации сети привело к распространению ransomware и простою операций на 3 дня. Как оцените совокупное влияние этого ИТ-дефекта?",
    
    ("ИТ- и киберриски", "Оценить риск (вероятность × влияние)", "Ревью рабочей документации"): 
        "Коллега оценил вероятность успешной DDoS-атаки как «низкую», потому что «у нас есть firewall». Достаточно ли такого обоснования для ревью?",
    
    ("ИТ- и киберриски", "Спроектировать контрольную процедуру", "Планирование и оценка существенности"): 
        "При планировании проверки вы хотите включить контроль ежеквартального review прав доступа привилегированных пользователей. Как обоснуете существенность этого контроля?",
    
    ("ИТ- и киберриски", "Спроектировать контрольную процедуру", "Разработка программы тестов"): 
        "Для обеспечения безопасности разработки вы проектируете контроль mandatory code review перед деплоем. Как опишете этот контроль в программе тестов?",
    
    ("ИТ- и киберриски", "Спроектировать контрольную процедуру", "Оценка дефектов и документирование"): 
        "Вы предложили контроль автоматического блокирования учетных записей после 5 неудачных попыток входа, но он не внедрен. Как задокументируете этот пробел?",
    
    ("ИТ- и киберриски", "Спроектировать контрольную процедуру", "Ревью рабочей документации"): 
        "При ревью видите, что предложенный ИТ-контроль требует manual review всех логов безопасности. Какие рекомендации дадите по внедрению SIEM?",
    
    ("ИТ- и киберриски", "Оценить эффективность существующего контроля", "Планирование и оценка существенности"): 
        "Контроль антивирусной защиты формально установлен, но обновления сигнатур запаздывают на 2 недели. Пересмотрите ли вы оценку киберрисков?",
    
    ("ИТ- и киберриски", "Оценить эффективность существующего контроля", "Разработка программы тестов"): 
        "Политика парольной сложности существует, но 30% учетных записей используют passwords из словаря. Как адаптируете программу тестов для оценки реальной гигиены паролей?",
    
    ("ИТ- и киберриски", "Оценить эффективность существующего контроля", "Оценка дефектов и документирование"): 
        "Контроль изменения конфигураций обходится через внесение изменений напрямую в продуктивную среду. Как классифицируете этот дефект эффективности ИТ-контроля?",
    
    ("ИТ- и киберриски", "Оценить эффективность существующего контроля", "Ревью рабочей документации"): 
        "В документации заявлена эффективность backup-процессов, но нет evidence successful restore tests за последний год. Примете ли такую оценку?",
    
    ("ИТ- и киберриски", "Критически разобрать чужую оценку риска", "Планирование и оценка существенности"): 
        "Коллега исключил из плана проверку cloud-инфраструктуры, считая ответственность провайдера достаточной. Как оспорите эту оценку с учетом shared responsibility model?",
    
    ("ИТ- и киберриски", "Критически разобрать чужую оценку риска", "Разработка программы тестов"): 
        "В программе тестов упор на network security, хотя основные инциденты связаны с social engineering. Как скорректируете баланс?",
    
    ("ИТ- и киберриски", "Критически разобрать чужую оценку риска", "Оценка дефектов и документирование"): 
        "Другой аудитор назвал отсутствие incident response plan «рекомендацией», а не критическим дефектом. Разделите ли вы эту точку зрения?",
    
    ("ИТ- и киберриски", "Критически разобрать чужую оценку риска", "Ревью рабочей документации"): 
        "При ревью обнаружили, что выводы о низких киберрисках основаны только на отчете внешнего аудитора годовой давности. Какие замечания внесете?",
    
    ("ИТ- и киберриски", "Сравнить подходы / фреймворки", "Планирование и оценка существенности"): 
        "Сравните подходы к оценке ИТ-рисков в COBIT и NIST Cybersecurity Framework. Какой фреймворк лучше интегрируется с нашим внутренним аудитом?",
    
    ("ИТ- и киберриски", "Сравнить подходы / фреймворки", "Разработка программы тестов"): 
        "Для тестирования ИТ-контролей можно использовать automated scanning tools или manual configuration review. Когда применим каждый метод и как это отразится на программе?",
    
    ("ИТ- и киберриски", "Сравнить подходы / фреймворки", "Оценка дефектов и документирование"): 
        "Сравните классификацию уязвимостей по CVSS и внутреннему рейтингу компании. Какой подход даст более actionable документацию для remediation?",
    
    ("ИТ- и киберриски", "Сравнить подходы / фреймворки", "Ревью рабочей документации"): 
        "Один аудитор документирует ИТ-риски через threat modeling, другой — через control gaps analysis. Какой формат обеспечит лучшее качество для ревью?",
    
    ("ИТ- и киберриски", "Предложить план митигации", "Планирование и оценка существенности"): 
        "Выявлено отсутствие шифрования данных at rest в базах с ПДн. Предложите план митигации и обоснуйте включение data protection в приоритетный периметр.",
    
    ("ИТ- и киберриски", "Предложить план митигации", "Разработка программы тестов"): 
        "Для снижения риска phishing вы предлагаете внедрить email gateway с sandboxing. Как протестируете эффективность этого решения в будущих проверках?",
    
    ("ИТ- и киберриски", "Предложить план митигации", "Оценка дефектов и документирование"): 
        "Обнаружен дефект: отсутствие multi-factor authentication для удаленного доступа. Предложите меры митигации и опишите их фиксацию в документации.",
    
    ("ИТ- и киберриски", "Предложить план митигации", "Ревью рабочей документации"): 
        "В ревьюируемом плане митигации киберрисков нет prioritization по criticality. Какие требования предъявите к roadmap внедрения контролей?",
    
    ("ИТ- и киберриски", "Проследить причинно-следственную цепочку риска", "Планирование и оценка существенности"): 
        "Отсутствие patch management → эксплуатация известной уязвимости → компрометация сервера → утечка данных клиентов. Как эта цепочка повлияет на оценку существенности ITSM?",
    
    ("ИТ- и киберриски", "Проследить причинно-следственную цепочку риска", "Разработка программы тестов"): 
        "Слабый access control → компрометация учетки сотрудника → lateral movement → шифрование данных. Какие звенья этой цепочки включите в программу тестов?",
    
    ("ИТ- и киберриски", "Проследить причинно-следственную цепочку риска", "Оценка дефектов и документирование"): 
        "Отсутствие network segmentation → распространение malware → остановка production → убытки от простоя. Как проследите и задокументируете эту цепочку?",
    
    ("ИТ- и киберриски", "Проследить причинно-следственную цепочку риска", "Ревью рабочей документации"): 
        "В документации описан ИТ-дефект, но не показана связь с бизнес-последствиями. Что потребуете добавить для обоснования критичности?",
}

print(f"Сгенерировано вопросов на данный момент: {len(questions_db) + len(project_risks_questions) + len(compliance_questions) + len(financial_risks_questions) + len(it_cyber_questions)}")
# Out:
# Сгенерировано вопросов на данный момент: 180

# %%
# Риски третьих сторон / поставщиков
third_party_questions = {
    ("Риски третьих сторон / поставщиков", "Объяснить концепцию/термин", "Планирование и оценка существенности"): 
        "Что такое «риск концентрации поставщиков» и как зависимость от единственного вендора влияет на определение materiality при планировании аудита закупок?",
    
    ("Риски третьих сторон / поставщиков", "Объяснить концепцию/термин", "Разработка программы тестов"): 
        "Объясните разницу между due diligence при онбординге поставщика и ongoing monitoring. Как эта разница отразится на дизайне тестовых процедур?",
    
    ("Риски третьих сторон / поставщиков", "Объяснить концепцию/термин", "Оценка дефектов и документирование"): 
        "Чем отличается «нарушение условий договора поставщиком» от «дефекта контроля управления третьими сторонами» при документировании?",
    
    ("Риски третьих сторон / поставщиков", "Объяснить концепцию/термин", "Ревью рабочей документации"): 
        "На какие документы (договоры, SLA, отчеты аудиторов поставщика) вы обращаете внимание при ревью документации по рискам третьих сторон?",
    
    ("Риски третьих сторон / поставщиков", "Идентифицировать риски в сценарии", "Планирование и оценка существенности"): 
        "Ключевой IT-поставщик использует субподрядчиков без вашего согласования. Какие риски третьих сторон заложите в план и каков уровень существенности?",
    
    ("Риски третьих сторон / поставщиков", "Идентифицировать риски в сценарии", "Разработка программы тестов"): 
        "Поставщик логистических услуг систематически нарушает сроки доставки, но штрафы не применяются. Какие тесты включите для проверки управления performance поставщиков?",
    
    ("Риски третьих сторон / поставщиков", "Идентифицировать риски в сценарии", "Оценка дефектов и документирование"): 
        "Обнаружено, что договор с стратегическим поставщиком не содержит положений о защите ПДн. Как классифицируете этот дефект и какие улики соберете?",
    
    ("Риски третьих сторон / поставщиков", "Идентифицировать риски в сценарии", "Ревью рабочей документации"): 
        "Младший аудитор выявил риски аффилированности поставщиков, но не проверил бенефициаров. Что добавите в его документацию?",
    
    ("Риски третьих сторон / поставщиков", "Оценить риск (вероятность × влияние)", "Планирование и оценка существенности"): 
        "Как определите аудиторский риск для поставщика, обеспечивающего 40% сырья, учитывая геополитическую нестабильность в регионе его деятельности?",
    
    ("Риски третьих сторон / поставщиков", "Оценить риск (вероятность × влияние)", "Разработка программы тестов"): 
        "Риск невыполнения обязательств ключевым поставщиком оценен как высокий. Какой объем выборки договоров и методов тестирования continuity plans включите в программу?",
    
    ("Риски третьих сторон / поставщиков", "Оценить риск (вероятность × влияние)", "Оценка дефектов и документирование"): 
        "Отсутствие альтернативных поставщиков привело к остановке производства на неделю при банкротстве основного вендора. Как оцените влияние этого дефекта?",
    
    ("Риски третьих сторон / поставщиков", "Оценить риск (вероятность × влияние)", "Ревью рабочей документации"): 
        "Коллега оценил вероятность срыва поставок как «низкую», основываясь только на долгосрочном контракте. Достаточно ли такого обоснования для ревью?",
    
    ("Риски третьих сторон / поставщиков", "Спроектировать контрольную процедуру", "Планирование и оценка существенности"): 
        "При планировании проверки вы хотите включить контроль ежегодного пересмотра рейтингов поставщиков. Как обоснуете существенность этого контроля для управления third-party рисками?",
    
    ("Риски третьих сторон / поставщиков", "Спроектировать контрольную процедуру", "Разработка программы тестов"): 
        "Для обеспечения качества услуг поставщиков вы проектируете контроль quarterly business reviews с фиксацией KPI. Как опишете этот контроль в программе тестов?",
    
    ("Риски третьих сторон / поставщиков", "Спроектировать контрольную процедуру", "Оценка дефектов и документирование"): 
        "Вы предложили контроль обязательной проверки поставщиков на санкции перед заключением договора, но он не внедрен. Как задокументируете этот пробел?",
    
    ("Риски третьих сторон / поставщиков", "Спроектировать контрольную процедуру", "Ревью рабочей документации"): 
        "При ревью видите, что предложенный контроль требует manual due diligence всех 500+ поставщиков. Какие рекомендации дадите по risk-based подходу?",
    
    ("Риски третьих сторон / поставщиков", "Оценить эффективность существующего контроля", "Планирование и оценка существенности"): 
        "Контроль тендерных процедур формально соблюдается, но 70% контрактов заключаются с единственным участником. Пересмотрите ли вы оценку рисков закупок?",
    
    ("Риски третьих сторон / поставщиков", "Оценить эффективность существующего контроля", "Разработка программы тестов"): 
        "Система оценки поставщиков существует, но рейтинги не обновлялись 2 года. Как адаптируете программу тестов для проверки актуальности vendor management?",
    
    ("Риски третьих сторон / поставщиков", "Оценить эффективность существующего контроля", "Оценка дефектов и документирование"): 
        "Контроль проверки финансовой устойчивости поставщиков обходится через использование устаревших отчетов. Как классифицируете этот дефект эффективности?",
    
    ("Риски третьих сторон / поставщиков", "Оценить эффективность существующего контроля", "Ревью рабочей документации"): 
        "В документации заявлена эффективность контроля contract compliance, но нет evidence мониторинга исполнения SLA. Примете ли такую оценку?",
    
    ("Риски третьих сторон / поставщиков", "Критически разобрать чужую оценку риска", "Планирование и оценка существенности"): 
        "Коллега исключил из плана проверку облачных провайдеров, считая их надежность достаточной. Как оспорите эту оценку с учетом рисков vendor lock-in?",
    
    ("Риски третьих сторон / поставщиков", "Критически разобрать чужую оценку риска", "Разработка программы тестов"): 
        "В программе тестов упор на ценовые условия, хотя основные риски связаны с качеством и непрерывностью поставок. Как скорректируете баланс?",
    
    ("Риски третьих сторон / поставщиков", "Критически разобрать чужую оценку риска", "Оценка дефектов и документирование"): 
        "Другой аудитор назвал отсутствие exit strategy для критичных поставщиков «лучшей практикой», а не дефектом. Разделите ли вы эту точку зрения?",
    
    ("Риски третьих сторон / поставщиков", "Критически разобрать чужую оценку риска", "Ревью рабочей документации"): 
        "При ревью обнаружили, что выводы о низких рисках поставщиков основаны только на заверениях procurement-директора. Какие замечания внесете?",
    
    ("Риски третьих сторон / поставщиков", "Сравнить подходы / фреймворки", "Планирование и оценка существенности"): 
        "Сравните подходы к оценке рисков поставщиков в ISO 20400 и внутренних best practices. Какой подход более комплексен для нашего аудита?",
    
    ("Риски третьих сторон / поставщиков", "Сравнить подходы / фреймворки", "Разработка программы тестов"): 
        "Для тестирования контроля поставщиков можно использовать supplier audits или questionnaire-based assessment. Когда применим каждый метод и как это отразится на программе?",
    
    ("Риски третьих сторон / поставщиков", "Сравнить подходы / фреймворки", "Оценка дефектов и документирование"): 
        "Сравните классификацию рисков поставщиков по SIG и CAIQ. Какой стандарт даст более структурированную документацию для нашего third-party风险管理?",
    
    ("Риски третьих сторон / поставщиков", "Сравнить подходы / фреймворки", "Ревью рабочей документации"): 
        "Один аудитор документирует риски поставщиков через vendor risk register, другой — через heat map по категориям spend. Какой формат лучше для ревью?",
    
    ("Риски третьих сторон / поставщиков", "Предложить план митигации", "Планирование и оценка существенности"): 
        "Выявлена высокая зависимость от одного поставщика комплектующих. Предложите план диверсификации и обоснуйте включение supplier development в приоритетный периметр.",
    
    ("Риски третьих сторон / поставщиков", "Предложить план митигации", "Разработка программы тестов"): 
        "Для снижения рисков качества вы предлагаете внедрить supplier scorecard с автоматическим расчетом. Как протестируете эффективность этой системы в будущих проверках?",
    
    ("Риски третьих сторон / поставщиков", "Предложить план митигации", "Оценка дефектов и документирование"): 
        "Обнаружен дефект: отсутствие contractual penalties за нарушение сроков. Предложите меры митигации и опишите их фиксацию в документации.",
    
    ("Риски третьих сторон / поставщиков", "Предложить план митигации", "Ревью рабочей документации"): 
        "В ревьюируемом плане митигации рисков поставщиков нет анализа cost of switching. Какие требования предъявите к оценке экономической целесообразности?",
    
    ("Риски третьих сторон / поставщиков", "Проследить причинно-следственную цепочку риска", "Планирование и оценка существенности"): 
        "Отсутствие due diligence → работа с неплатежеспособным поставщиком → срыв поставок → потеря клиентов. Как эта цепочка повлияет на оценку существенности onboarding-процессов?",
    
    ("Риски третьих сторон / поставщиков", "Проследить причинно-следственную цепочку риска", "Разработка программы тестов"): 
        "Неконтролируемые субподрядчики → нарушение требований безопасности → инцидент с данными → регуляторные штрафы. Какие звенья включите в программу тестов?",
    
    ("Риски третьих сторон / поставщиков", "Проследить причинно-следственную цепочку риска", "Оценка дефектов и документирование"): 
        "Отсутствие мониторинга финансового состояния поставщика → его банкротство → экстренный поиск замены → рост затрат. Как проследите и задокументируете эту цепочку?",
    
    ("Риски третьих сторон / поставщиков", "Проследить причинно-следственную цепочку риска", "Ревью рабочей документации"): 
        "В документации описан дефект управления поставщиками, но не показана связь с операционными потерями. Что потребуете добавить?",
}

# Стратегические риски
strategic_risks_questions = {
    ("Стратегические риски", "Объяснить концепцию/термин", "Планирование и оценка существенности"): 
        "Что такое «риск стратегического несоответствия» и как misalignment между стратегией и операционной деятельностью влияет на границы аудиторской проверки?",
    
    ("Стратегические риски", "Объяснить концепцию/термин", "Разработка программы тестов"): 
        "Объясните разницу между strategic risk и operational risk. Как эта разница повлияет на выбор метрик и методов тестирования в программе?",
    
    ("Стратегические риски", "Объяснить концепцию/термин", "Оценка дефектов и документирование"): 
        "Чем отличается «недостижение стратегической цели» от «дефекта стратегического управления» при документировании результатов проверки?",
    
    ("Стратегические риски", "Объяснить концепцию/термин", "Ревью рабочей документации"): 
        "На какие стратегические документы (стратегия, дорожные карты, KPI) вы обращаете внимание при ревью документации по стратегическим рискам?",
    
    ("Стратегические риски", "Идентифицировать риски в сценарии", "Планирование и оценка существенности"): 
        "Компания инвестирует в устаревающую технологию, игнорируя тренды цифровизации отрасли. Какие стратегические риски заложите в план и каков уровень существенности?",
    
    ("Стратегические риски", "Идентифицировать риски в сценарии", "Разработка программы тестов"): 
        "Стратегия выхода на новый рынок не подкреплена анализом конкурентов и регуляторных барьеров. Какие тесты включите для проверки quality strategic planning?",
    
    ("Стратегические риски", "Идентифицировать риски в сценарии", "Оценка дефектов и документирование"): 
        "Обнаружено, что стратегические инициативы не имеют owners и measurable milestones. Как классифицируете этот дефект и какие улики соберете?",
    
    ("Стратегические риски", "Идентифицировать риски в сценарии", "Ревью рабочей документации"): 
        "Младший аудитор выявил риски cannibalization продуктов, но не оценил влияние на long-term profitability. Что добавите в его документацию?",
    
    ("Стратегические риски", "Оценить риск (вероятность × влияние)", "Планирование и оценка существенности"): 
        "Как определите аудиторский риск для стратегической инициативы с высокой неопределенностью рынка, но потенциалом трансформации бизнеса?",
    
    ("Стратегические риски", "Оценить риск (вероятность × влияние)", "Разработка программы тестов"): 
        "Риск неудачи M&A сделки оценен как высокий из-за cultural differences. Какой объем выборки integration plans и методов тестирования включите в программу?",
    
    ("Стратегические риски", "Оценить риск (вероятность × влияние)", "Оценка дефектов и документирование"): 
        "Отсутствие scenario planning привело к неподготовленности к изменению регуляторной среды и потере доли рынка. Как оцените влияние этого стратегического дефекта?",
    
    ("Стратегические риски", "Оценить риск (вероятность × влияние)", "Ревью рабочей документации"): 
        "Коллега оценил вероятность провала новой бизнес-модели как «низкую», основываясь только на оптимистичных прогнозах. Достаточно ли этого для ревью?",
    
    ("Стратегические риски", "Спроектировать контрольную процедуру", "Планирование и оценка существенности"): 
        "При планировании проверки вы хотите включить контроль ежеквартального review strategic assumptions. Как обоснуете существенность этого контроля для стратегических рисков?",
    
    ("Стратегические риски", "Спроектировать контрольную процедуру", "Разработка программы тестов"): 
        "Для обеспечения alignment стратегии и операций вы проектируете контроль cascade strategic KPI до уровня подразделений. Как опишете этот контроль в программе?",
    
    ("Стратегические риски", "Спроектировать контрольную процедуру", "Оценка дефектов и документирование"): 
        "Вы предложили контроль mandatory stress-testing стратегических планов, но он не внедрен. Как задокументируете этот пробел в стратегическом управлении?",
    
    ("Стратегические риски", "Спроектировать контрольную процедуру", "Ревью рабочей документации"): 
        "При ревью видите, что предложенный стратегический контроль требует annual deep-dive analysis всех инициатив. Какие рекомендации дадите по фокусировке на critical few?",
    
    ("Стратегические риски", "Оценить эффективность существующего контроля", "Планирование и оценка существенности"): 
        "Контроль strategic review формально проводится, но решения не влияют на resource allocation. Пересмотрите ли вы оценку стратегических рисков?",
    
    ("Стратегические риски", "Оценить эффективность существующего контроля", "Разработка программы тестов"): 
        "Система стратегического планирования существует, но нет linkage с budgeting process. Как адаптируете программу тестов для проверки integration?",
    
    ("Стратегические риски", "Оценить эффективность существующего контроля", "Оценка дефектов и документирование"): 
        "Контроль мониторинга конкурентной среды обходится через использование устаревших market research данных. Как классифицируете этот дефект эффективности?",
    
    ("Стратегические риски", "Оценить эффективность существующего контроля", "Ревью рабочей документации"): 
        "В документации заявлена эффективность strategic governance, но нет evidence board-level discussion ключевых рисков. Примете ли такую оценку?",
    
    ("Стратегические риски", "Критически разобрать чужую оценку риска", "Планирование и оценка существенности"): 
        "Коллега исключил из плана проверку digital transformation стратегии, считая ее IT-проектом. Как оспорите эту оценку с учетом business model implications?",
    
    ("Стратегические риски", "Критически разобрать чужую оценку риска", "Разработка программы тестов"): 
        "В программе тестов упор на финансовые метрики, хотя основные стратегические риски связаны с customer experience и brand equity. Как скорректируете баланс?",
    
    ("Стратегические риски", "Критически разобрать чужую оценку риска", "Оценка дефектов и документирование"): 
        "Другой аудитор назвал отсутствие competitive intelligence function «опциональной практикой», а не дефектом. Разделите ли вы эту точку зрения?",
    
    ("Стратегические риски", "Критически разобрать чужую оценку риска", "Ревью рабочей документации"): 
        "При ревью обнаружили, что выводы о низких стратегических рисках основаны только на презентации CEO. Какие замечания внесете?",
    
    ("Стратегические риски", "Сравнить подходы / фреймворки", "Планирование и оценка существенности"): 
        "Сравните подходы к оценке стратегических рисков в Balanced Scorecard и OKR framework. Какой подход лучше интегрируется с нашим внутренним аудитом?",
    
    ("Стратегические риски", "Сравнить подходы / фреймворки", "Разработка программы тестов"): 
        "Для тестирования стратегических контролей можно использовать scenario analysis или sensitivity testing. Когда применим каждый метод и как это отразится на программе?",
    
    ("Стратегические риски", "Сравнить подходы / фреймворки", "Оценка дефектов и документирование"): 
        "Сравните классификацию стратегических рисков по PESTLE и SWOT. Какой фреймворк даст более actionable документацию для strategic decision-making?",
    
    ("Стратегические риски", "Сравнить подходы / фреймворки", "Ревью рабочей документации"): 
        "Один аудитор документирует стратегические риски через strategy map, другой — через risk register. Какой формат обеспечит лучшее качество для ревью?",
    
    ("Стратегические риски", "Предложить план митигации", "Планирование и оценка существенности"): 
        "Выявлено отсутствие diversification revenue streams при зависимости от одного продукта. Предложите план диверсификации и обоснуйте включение в приоритетный периметр.",
    
    ("Стратегические риски", "Предложить план митигации", "Разработка программы тестов"): 
        "Для снижения рисков market disruption вы предлагаете внедрить innovation pipeline management. Как протестируете эффективность этого процесса в будущих проверках?",
    
    ("Стратегические риски", "Предложить план митигации", "Оценка дефектов и документирование"): 
        "Обнаружен дефект: отсутствие formal strategy review cycle. Предложите меры митигации и опишите их фиксацию в документации.",
    
    ("Стратегические риски", "Предложить план митигации", "Ревью рабочей документации"): 
        "В ревьюируемом плане митигации стратегических рисков нет clear ownership. Какие требования предъявите к accountability structure?",
    
    ("Стратегические риски", "Проследить причинно-следственную цепочку риска", "Планирование и оценка существенности"): 
        "Игнорирование ESG-трендов → репутационный ущерб → отток инвесторов → снижение капитализации. Как эта цепочка повлияет на оценку существенности sustainability strategy?",
    
    ("Стратегические риски", "Проследить причинно-следственную цепочку риска", "Разработка программы тестов"): 
        "Отсутствие talent strategy → дефицит ключевых компетенций → невозможность реализации стратегии → потеря конкурентных преимуществ. Какие звенья включите в программу?",
    
    ("Стратегические риски", "Проследить причинно-следственную цепочку риска", "Оценка дефектов и документирование"): 
        "Неверная оценка market size → overinvestment в непрофильные активы → снижение ROI → давление акционеров. Как проследите и задокументируете эту цепочку?",
    
    ("Стратегические риски", "Проследить причинно-следственную цепочку риска", "Ревью рабочей документации"): 
        "В документации описан стратегический дефект, но не показана связь с financial performance. Что потребуете добавить для обоснования материальности?",
}

print(f"Сгенерировано вопросов на данный момент: {len(questions_db) + len(project_risks_questions) + len(compliance_questions) + len(financial_risks_questions) + len(it_cyber_questions) + len(third_party_questions) + len(strategic_risks_questions)}")
# Out:
# Сгенерировано вопросов на данный момент: 252

# %%
# Риски мошенничества (fraud)
fraud_risks_questions = {
    ("Риски мошенничества (fraud)", "Объяснить концепцию/термин", "Планирование и оценка существенности"): 
        "Что такое «fraud triangle» и как наличие всех трех элементов (давление, возможность, рационализация) влияет на определение уровня аудиторского риска при планировании?",
    
    ("Риски мошенничества (fraud)", "Объяснить концепцию/термин", "Разработка программы тестов"): 
        "Объясните разницу между fraud prevention и fraud detection controls. Как эта разница повлияет на дизайн тестовых процедур в программе проверки?",
    
    ("Риски мошенничества (fraud)", "Объяснить концепцию/термин", "Оценка дефектов и документирование"): 
        "Чем отличается «подозрение на мошенничество» от «подтвержденного случая fraud» при документировании результатов расследования?",
    
    ("Риски мошенничества (fraud)", "Объяснить концепцию/термин", "Ревью рабочей документации"): 
        "На какие элементы доказательной базы (документы, интервью, forensic analysis) вы обращаете внимание при ревью документации по fraud-рискам?",
    
    ("Риски мошенничества (fraud)", "Идентифицировать риски в сценарии", "Планирование и оценка существенности"): 
        "Финансовый директор единолично утверждает крупные платежи без вторичного контроля. Какие fraud-риски заложите в план и каков уровень существенности?",
    
    ("Риски мошенничества (fraud)", "Идентифицировать риски в сценарии", "Разработка программы тестов"): 
        "Сотрудник отдела закупок живет не по средствам, часто берет дорогие отпуска. Какие тесты включите для выявления возможных kickback схем?",
    
    ("Риски мошенничества (fraud)", "Идентифицировать риски в сценарии", "Оценка дефектов и документирование"): 
        "Обнаружены фиктивные акты выполненных работ от компании, зарегистрированной на родственника менеджера. Как классифицируете этот случай и какие улики соберете?",
    
    ("Риски мошенничества (fraud)", "Идентифицировать риски в сценарии", "Ревью рабочей документации"): 
        "Младший аудитор выявил аномалии в расходах на представительские цели, но не провел deeper dive анализ. Что добавите в его документацию?",
    
    ("Риски мошенничества (fraud)", "Оценить риск (вероятность × влияние)", "Планирование и оценка существенности"): 
        "Как определите аудиторский риск fraud для подразделения с высокой текучестью кадров и слабым тоном сверху (tone at the top)?",
    
    ("Риски мошенничества (fraud)", "Оценить риск (вероятность × влияние)", "Разработка программы тестов"): 
        "Риск collusion сотрудников при проведении тендеров оценен как высокий. Какой объем выборки тендерной документации и методов data analytics включите в программу?",
    
    ("Риски мошенничества (fraud)", "Оценить риск (вероятность × влияние)", "Оценка дефектов и документирование"): 
        "Отсутствие segregation of duties привело к хищению 10 млн руб. через создание фиктивных поставщиков. Как оцените совокупное влияние этого fraud-дефекта?",
    
    ("Риски мошенничества (fraud)", "Оценить риск (вероятность × влияние)", "Ревью рабочей документации"): 
        "Коллега оценил вероятность внутреннего мошенничества как «низкую», потому что «у нас лояльный коллектив». Достаточно ли такого обоснования для ревью?",
    
    ("Риски мошенничества (fraud)", "Спроектировать контрольную процедуру", "Планирование и оценка существенности"): 
        "При планировании проверки вы хотите включить контроль mandatory vacation для сотрудников на чувствительных позициях. Как обоснуете существенность этого антифрод-контроля?",
    
    ("Риски мошенничества (fraud)", "Спроектировать контрольную процедуру", "Разработка программы тестов"): 
        "Для выявления fraudulent disbursements вы проектируете контроль automated matching платежей с данными о бенефициарах. Как опишете этот контроль в программе?",
    
    ("Риски мошенничества (fraud)", "Спроектировать контрольную процедуру", "Оценка дефектов и документирование"): 
        "Вы предложили контроль whistleblower hotline с гарантией анонимности, но он не внедрен. Как задокументируете этот пробел в fraud prevention?",
    
    ("Риски мошенничества (fraud)", "Спроектировать контрольную процедуру", "Ревью рабочей документации"): 
        "При ревью видите, что предложенный fraud-контроль требует manual review всех транзакций. Какие рекомендации дадите по внедрению anomaly detection algorithms?",
    
    ("Риски мошенничества (fraud)", "Оценить эффективность существующего контроля", "Планирование и оценка существенности"): 
        "Контроль background checks при найме формально проводится, но не проверяются реальные references. Пересмотрите ли вы оценку fraud-рисков?",
    
    ("Риски мошенничества (fraud)", "Оценить эффективность существующего контроля", "Разработка программы тестов"): 
        "Система approval workflows существует, но managers approve payments rubber-stamp style без проверки. Как адаптируете программу тестов?",
    
    ("Риски мошенничества (fraud)", "Оценить эффективность существующего контроля", "Оценка дефектов и документирование"): 
        "Контроль инвентаризации обходится через collusion складских работников и счетчиков. Как классифицируете этот дефект эффективности anti-fraud контроля?",
    
    ("Риски мошенничества (fraud)", "Оценить эффективность существующего контроля", "Ревью рабочей документации"): 
        "В документации заявлена эффективность fraud monitoring, но нет evidence investigation любых red flags за последний год. Примете ли такую оценку?",
    
    ("Риски мошенничества (fraud)", "Критически разобрать чужую оценку риска", "Планирование и оценка существенности"): 
        "Коллега исключил из плана проверку expense reimbursements, считая суммы несущественными. Как оспорите эту оценку с учетом risk of systematic small frauds?",
    
    ("Риски мошенничества (fraud)", "Критически разобрать чужую оценку риска", "Разработка программы тестов"): 
        "В программе тестов упор на substantive testing, хотя основные fraud-риски связаны с override of controls management. Как скорректируете баланс?",
    
    ("Риски мошенничества (fraud)", "Критически разобрать чужую оценку риска", "Оценка дефектов и документирование"): 
        "Другой аудитор назвал отсутствие fraud risk assessment «рекомендацией», а не критическим дефектом. Разделите ли вы эту точку зрения?",
    
    ("Риски мошенничества (fraud)", "Критически разобрать чужую оценку риска", "Ревью рабочей документации"): 
        "При ревью обнаружили, что выводы о низких fraud-рисках основаны только на отсутствии подтвержденных случаев. Какие замечания внесете?",
    
    ("Риски мошенничества (fraud)", "Сравнить подходы / фреймворки", "Планирование и оценка существенности"): 
        "Сравните подходы к оценке fraud-рисков в ISA 240 и ACFE guidelines. Какой подход более практичен для нашего внутреннего аудита?",
    
    ("Риски мошенничества (fraud)", "Сравнить подходы / фреймворки", "Разработка программы тестов"): 
        "Для выявления fraud можно использовать Benford's Law analysis или transaction pattern mining. Когда применим каждый метод и как это отразится на программе?",
    
    ("Риски мошенничества (fraud)", "Сравнить подходы / фреймворки", "Оценка дефектов и документирование"): 
        "Сравните классификацию fraud schemes по Fraud Tree ACFE и внутренней типологии. Какой стандарт даст более релевантную структуру для нашего документирования?",
    
    ("Риски мошенничества (fraud)", "Сравнить подходы / фреймворки", "Ревью рабочей документации"): 
        "Один аудитор документирует fraud-риски через fraud risk register, другой — через heat map по fraud triangle components. Какой формат лучше для ревью?",
    
    ("Риски мошенничества (fraud)", "Предложить план митигации", "Планирование и оценка существенности"): 
        "Выявлены признаки conflict of interest у руководителей закупок. Предложите план митигации и обоснуйте включение ethics & compliance в приоритетный периметр.",
    
    ("Риски мошенничества (fraud)", "Предложить план митигации", "Разработка программы тестов"): 
        "Для снижения риска asset misappropriation вы предлагаете внедрить continuous monitoring систему. Как протестируете ее эффективность в будущих проверках?",
    
    ("Риски мошенничества (fraud)", "Предложить план митигации", "Оценка дефектов и документирование"): 
        "Обнаружен дефект: отсутствие ротации сотрудников на fraud-sensitive positions. Предложите меры митигации и опишите их фиксацию в документации.",
    
    ("Риски мошенничества (fraud)", "Предложить план митигации", "Ревью рабочей документации"): 
        "В ревьюируемом плане митигации fraud-рисков нет clear escalation procedure. Какие требования предъявите к incident response framework?",
    
    ("Риски мошенничества (fraud)", "Проследить причинно-следственную цепочку риска", "Планирование и оценка существенности"): 
        "Слабый tone at the top → нормализация unethical behavior → систематическое завышение расходов → финансовые потери. Как эта цепочка повлияет на оценку существенности corporate culture?",
    
    ("Риски мошенничества (fraud)", "Проследить причинно-следственную цепочку риска", "Разработка программы тестов"): 
        "Отсутствие background checks → найм сотрудника с criminal history → доступ к чувствительным данным → утечка информации. Какие звенья включите в программу тестов?",
    
    ("Риски мошенничества (fraud)", "Проследить причинно-следственную цепочку риска", "Оценка дефектов и документирование"): 
        "Override of controls руководством → фиктивные продажи → завышение выручки → введение инвесторов в заблуждение. Как проследите и задокументируете эту цепочку?",
    
    ("Риски мошенничества (fraud)", "Проследить причинно-следственную цепочку риска", "Ревью рабочей документации"): 
        "В документации описан fraud-случай, но не показана root cause analysis. Что потребуете добавить для предотвращения recurrence?",
}

print(f"Всего сгенерировано вопросов: {len(questions_db) + len(project_risks_questions) + len(compliance_questions) + len(financial_risks_questions) + len(it_cyber_questions) + len(third_party_questions) + len(strategic_risks_questions) + len(fraud_risks_questions)}")
# Out:
# Всего сгенерировано вопросов: 288

# %%
# Объединяем все вопросы в один список
all_questions = {}
all_questions.update(questions_db)
all_questions.update(project_risks_questions)
all_questions.update(compliance_questions)
all_questions.update(financial_risks_questions)
all_questions.update(it_cyber_questions)
all_questions.update(third_party_questions)
all_questions.update(strategic_risks_questions)
all_questions.update(fraud_risks_questions)

# Преобразуем в формат JSON
json_output = []
for (domain_a, domain_b, domain_c), question in all_questions.items():
    json_output.append({
        "domain_a": domain_a,
        "domain_b": domain_b,
        "domain_c": domain_c,
        "question": question
    })

# Проверяем количество
print(f"Всего вопросов в JSON: {len(json_output)}")
print(f"Ожидаемое количество: 8 осей A × 9 осей B × 4 оси C = {8 * 9 * 4}")

# Сохраняем в файл
with open('audit_interview_questions.json', 'w', encoding='utf-8') as f:
    json.dump(json_output, f, ensure_ascii=False, indent=2)

print("\nФайл audit_interview_questions.json успешно создан!")
print(f"\nПример первых 3 вопросов:")
for i, q in enumerate(json_output[:3]):
    print(f"\n{i+1}. [{q['domain_a']}] / [{q['domain_b']}] / [{q['domain_c']}]")
    print(f"   {q['question']}")
# Out:
# Всего вопросов в JSON: 288
# Ожидаемое количество: 8 осей A × 9 осей B × 4 оси C = 288
#
# Файл audit_interview_questions.json успешно создан!
#
# Пример первых 3 вопросов:
#
# 1. [Операционные риски процессов] / [Объяснить концепцию/термин] / [Планирование и оценка существенности]
#    На основе каких критериев вы разделяете операционные риски бизнес-процесса на «критичные» и «незначительные», и как величина финансового порога существенности влияет на границы периметра нашей проверки?
#
# 2. [Операционные риски процессов] / [Объяснить концепцию/термин] / [Разработка программы тестов]
#    Каким образом в создаваемой программе тестов вы планируете разграничивать процедуры проверки дизайна контрольных процедур от процедур тестирования их фактической операционной эффективности?
#
# 3. [Операционные риски процессов] / [Объяснить концепцию/термин] / [Оценка дефектов и документирование]
# ...
